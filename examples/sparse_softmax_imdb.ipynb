# %%
import os

os.environ['backend'] = "pytorch"
import psfit
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

import psfit as pf
from psfit import Linear
from psfit.data import Imdb, DataLoader
from psfit.module import SoftmaxLoss
from psfit.optim import LocalTrainer, SGD, ProjectionSparsifier, L1, L2
from psfit.optim.optimizer import Admm

# %%
backend = psfit.get_backend()
print(f"Backend name: {backend.name}")
print(f"Backend type: {backend}")
# Out:
# Backend name: PyTorch
# Backend type: backend(dev=cuda, api=pytorch)

# %%
ds = Imdb("../data/imdb_data.npz", cv = True, cv_size = 0.1)
loader = DataLoader(dataset = ds, batch_size = len(ds) // 2, shuffle = True, report = True)
# Out:
# Loading batches to cuda
#
# Number of batches loaded: 2

# %%
print("dataset:", ds)
# Out:
# dataset: IMDB()

# %%
x_cv, y_cv = ds.cv_data
x_tr, y_tr = ds.train_data

# %%
n, c = ds.number_of_features, ds.number_of_classes
model = Linear(in_features = n, out_features = c)

# %%
trainer = LocalTrainer(
    dataloader = loader,
    loss = SoftmaxLoss(),
    optimizer = SGD(model, learning_rate = 0.05),
    verbose = False
)


def predict(x):
    logits = x @ model.parameters.array().cpu().numpy()
    predictions = np.argmax(logits, axis = 1, keepdims = True)
    return predictions

# %%
penalty = 20
l0_reg = ProjectionSparsifier(density = 500)
l1_reg = L1(admm_penalty = penalty, l1_penalty = 0.002)
l2_reg = L2(admm_penalty = penalty, l2_penalty = 0.01)

# %%
regularizers = {
    "L0": [l0_reg],
    "Lasso": [l1_reg],
    "Ridge": [l2_reg],
    "Elastic Net": [l2_reg, l1_reg],
}

loss_values = {
    "L0": [],
    "Lasso": [],
    "Ridge": [],
    "Elastic Net": [],

}

primal_error_values = {
    "L0": [],
    "Lasso": [],
    "Ridge": [],
    "Elastic Net": [],
}
train_accuracy = {
    "L0": [],
    "Lasso": [],
    "Ridge": [],
    "Elastic Net": [],

}
validation_accuracy = {
    "L0": [],
    "Lasso": [],
    "Ridge": [],
    "Elastic Net": [],

}
weights = {
    "L0": None,
    "Lasso": None,
    "Ridge": None,
    "Elastic Net": None,
}

iters = 600
epoch = 0

for reg_name, aggregators in regularizers.items():
    print(f"Training with {reg_name}")

    model.init_params()

    optimizer = Admm(trainer = trainer, aggregators = aggregators)

    for epoch in range(iters):

        loss, err = optimizer.step(penalty = penalty)
        loss_values[reg_name].append(loss)

        pred_training = predict(x_tr)
        pred_validation = predict(x_cv)

        train_acc = accuracy_score(y_tr, pred_training)
        cv_acc = accuracy_score(y_cv, pred_validation)

        train_accuracy[reg_name].append(train_acc)
        validation_accuracy[reg_name].append(cv_acc)
        primal_error_values[reg_name].append(err)

        weights[reg_name] = model.parameters

        if (epoch + 1) % 100 == 0:
            print(
                f"Epoch {epoch + 1:3d}: Loss = {loss:.4f}, Error = {err:.6f}, Training = {train_acc:.6f}, Validation = {cv_acc:.6f}, Model: {reg_name}")
    print()
# Out:
# Training with L0
# /home/alirezaolama/projects/PsFIT/psfit/autodiff.py:323: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3697.)
#   value = value.array().T
# Epoch 100: Loss = 0.4960, Error = 0.000000, Training = 0.810356, Validation = 0.813600, Model: L0
# Epoch 200: Loss = 0.4395, Error = 0.000000, Training = 0.828711, Validation = 0.826400, Model: L0
# Epoch 300: Loss = 0.4108, Error = 0.000000, Training = 0.838533, Validation = 0.834000, Model: L0
# Epoch 400: Loss = 0.3928, Error = 0.000000, Training = 0.842889, Validation = 0.838400, Model: L0
# Epoch 500: Loss = 0.3801, Error = 0.000000, Training = 0.847067, Validation = 0.841600, Model: L0
# Epoch 600: Loss = 0.3706, Error = 0.000000, Training = 0.850622, Validation = 0.844000, Model: L0
#
# Training with Lasso
# Epoch 100: Loss = 0.5177, Error = 0.000000, Training = 0.806178, Validation = 0.809600, Model: Lasso
# Epoch 200: Loss = 0.4682, Error = 0.000000, Training = 0.819867, Validation = 0.821200, Model: Lasso
# Epoch 300: Loss = 0.4443, Error = 0.000000, Training = 0.826178, Validation = 0.824800, Model: Lasso
# Epoch 400: Loss = 0.4300, Error = 0.000000, Training = 0.830311, Validation = 0.828400, Model: Lasso
# Epoch 500: Loss = 0.4202, Error = 0.000000, Training = 0.833422, Validation = 0.829200, Model: Lasso
# Epoch 600: Loss = 0.4131, Error = 0.000000, Training = 0.835689, Validation = 0.830400, Model: Lasso
#
# Training with Ridge
# Epoch 100: Loss = 0.4808, Error = 0.000000, Training = 0.831067, Validation = 0.830000, Model: Ridge
# Epoch 200: Loss = 0.4247, Error = 0.000000, Training = 0.850311, Validation = 0.842400, Model: Ridge
# Epoch 300: Loss = 0.3974, Error = 0.000000, Training = 0.859067, Validation = 0.845600, Model: Ridge
# Epoch 400: Loss = 0.3811, Error = 0.000000, Training = 0.863644, Validation = 0.851200, Model: Ridge
# Epoch 500: Loss = 0.3702, Error = 0.000000, Training = 0.867778, Validation = 0.853200, Model: Ridge
# Epoch 600: Loss = 0.3624, Error = 0.000000, Training = 0.870444, Validation = 0.856800, Model: Ridge
#
# Training with Elastic Net
# Epoch 100: Loss = 0.5229, Error = 0.000000, Training = 0.805600, Validation = 0.809600, Model: Elastic Net
# Epoch 200: Loss = 0.4784, Error = 0.000000, Training = 0.819022, Validation = 0.818000, Model: Elastic Net
# Epoch 300: Loss = 0.4584, Error = 0.000000, Training = 0.825467, Validation = 0.822800, Model: Elastic Net
# Epoch 400: Loss = 0.4474, Error = 0.000000, Training = 0.828044, Validation = 0.826800, Model: Elastic Net

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (8, 2.5))
epochs = list(range(iters))

colors = ['#d62728', '#9467bd', '#1f77b4', '#ff7f0e', '#2ca02c',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

markers = ['o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'D']

i = 0
for model_name, loss_value in loss_values.items():
    ax1.plot(epochs, loss_value, linestyle = '-', color = colors[i], marker = markers[i], markersize = 4,
             label = model_name, markevery = 20)
    ax1.set_xlabel('Epochs', fontsize = 12)
    ax1.set_ylabel('Loss', fontsize = 12)
    ax1.grid(True, which = 'both', linestyle = '--', linewidth = 0.5)
    ax1.legend()
    i += 1

i = 0
for model_name, primal_error in primal_error_values.items():
    ax2.plot(epochs, primal_error, linestyle = '-', color = colors[i], marker = markers[i], markersize = 4,
             label = model_name, markevery = 20)
    ax2.set_xlabel('Epochs', fontsize = 12)
    ax2.set_ylabel('Error', fontsize = 12)
    ax2.grid(True, which = 'both', linestyle = '--', linewidth = 0.5)
    ax2.legend()
    i += 1

plt.xlabel('Epochs', fontsize = 14)  # X-axis label
plt.ylabel('Loss', fontsize = 14)  # Y-axis label

# Add a grid for better readability
plt.grid(True)

# Add a legend
plt.legend()

# Show the plot
plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (8, 2.5))
i = 0
for model_name, train_acc in train_accuracy.items():
    ax1.plot(epochs, train_acc, linestyle = '-', color = colors[i], marker = markers[i], markersize = 4,
             label = model_name, markevery = 20)
    ax1.set_xlabel('Epochs', fontsize = 12)
    ax1.set_ylabel('Training Accuracy', fontsize = 12)
    ax1.grid(True, which = 'both', linestyle = '--', linewidth = 0.5)
    ax1.legend()
    i += 1

i = 0
for model_name, validation_acc in validation_accuracy.items():
    ax2.plot(epochs, validation_acc, linestyle = '-', color = colors[i], marker = markers[i], markersize = 4,
             label = model_name, markevery = 20)
    ax2.set_xlabel('Epochs', fontsize = 12)
    ax2.set_ylabel('Validation Accuracy', fontsize = 12)
    ax2.grid(True, which = 'both', linestyle = '--', linewidth = 0.5)
    ax2.legend()
    i += 1

plt.tight_layout()
plt.savefig(f"../figures/training_validation_{ds.__class__.__name__.lower()}.pdf",
            dpi = 300)

# %%
models = [key for key in weights.keys()]
sparsity = [len(np.nonzero(weights[k].array()[:, 0])) for k in weights.keys()]
sparsity
# Out:
# [500, 414, 9998, 433]

# %%
# Create the bar plot
plt.figure(figsize = (6, 5))
bars = plt.bar(models, sparsity, color = 'skyblue', edgecolor = 'black', width = 0.5, )

plt.xlabel('Models', fontsize = 12)
plt.ylabel('Non-zero Weights Count', fontsize = 12)

# Add values on top of the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height,
             f'{height}', ha = 'center', va = 'bottom', fontsize = 10, fontweight = 'bold')

# Customize ticks and layout for better presentation
plt.xticks(rotation = 45, ha = 'right', fontsize = 12)
plt.tight_layout()

# Show the plot
plt.show()

# %%
digit = 1
size = (100, 100)
w_l0 = weights['L0'].array()[:, digit].cpu()
w_l1 = weights['Lasso'].array()[:, digit].cpu()
w_l12 = weights['Elastic Net'].array()[:, digit].cpu()
w_r = weights['Ridge'].array()[:, digit].cpu()
fig, ax = plt.subplots(2, 2, figsize = (7, 4))

ax[0, 0].spy(w_r.reshape(size), aspect = 'auto', markersize = 1)
ax[0, 0].set_title("Ridge")
ax[0, 0].axis('off')

ax[0, 1].spy(w_l0.reshape(size), aspect = 'auto', markersize = 1)
ax[0, 1].set_title("L0")
ax[0, 1].axis('off')

ax[1, 0].spy(w_l1.reshape(size), aspect = 'auto', markersize = 1)
ax[1, 0].set_title("Lasso")
ax[1, 0].axis('off')

ax[1, 1].spy(w_l12.reshape(size), aspect = 'auto', markersize = 1)
ax[1, 1].set_title("Elastic Net")
ax[1, 1].axis('off')
plt.tight_layout()

# %%
fig, ax = plt.subplots(2, 2, figsize = (7, 4))

ax[0, 0].imshow(w_r.reshape(size), aspect = 'auto', cmap = "binary")
ax[0, 0].set_title("Ridge")
ax[0, 0].axis('off')

ax[0, 1].imshow(w_l0.reshape(size), aspect = 'auto', cmap = "binary")
ax[0, 1].set_title("L0")
ax[0, 1].axis('off')

ax[1, 0].imshow(w_l1.reshape(size), aspect = 'auto', cmap = "binary")
ax[1, 0].set_title("Lasso")
ax[1, 0].axis('off')

ax[1, 1].imshow(w_l12.reshape(size), aspect = 'auto', cmap = "binary")
ax[1, 1].set_title("Elastic Net")
ax[1, 1].axis('off')
# Out:
# (np.float64(-0.5), np.float64(99.5), np.float64(99.5), np.float64(-0.5))

# %%
reversed_order = {value: key for key, value in ds.get_word_index().items()}

# %%
fig, ax = plt.subplots(1, 4, figsize = (10, 3))

N = 5

i = 0
for model_name, weight in weights.items():
    pos_coeffs_index = reversed(np.argsort(weight.array().cpu()[:, 1])[-N:])
    neg_coeffs_index = reversed(np.argsort(weight.array().cpu()[:, 0])[-N:])

    pos_weights = weight.array().cpu()[:, 1][pos_coeffs_index]
    neg_weights = weight.array().cpu()[:, 0][neg_coeffs_index]

    pos_words = [reversed_order.get(int(i) - 3, "?") for i in pos_coeffs_index]
    neg_words = [reversed_order.get(int(i) - 3, "?") for i in neg_coeffs_index]

    ax[i].barh(pos_words, pos_weights)
    ax[i].barh(neg_words, neg_weights)
    ax[i].barh(pos_words, pos_weights, color = 'green')
    ax[i].set_title(f"{model_name} - Positive Weights")

    ax[i].barh(neg_words, neg_weights, color = 'red')
    ax[i].set_title(f"{model_name} - Negative Weights")
    i = i + 1

plt.tight_layout()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

for model_name, weight in weights.items():
    pos_weights = weight.cpu().numpy()[:, 1]
    neg_weights = weight.cpu().numpy()[:, 0]

    # Combine positive and negative weights for a word cloud
    word_freq = {reversed_order.get(int(idx) - 3, "?"): abs(pos_weights[idx] + neg_weights[idx])
                 for idx in range(len(pos_weights))}

    # Create a word cloud
    wordcloud = WordCloud(background_color = 'white', width = 800, height = 400).generate_from_frequencies(word_freq)

    # Plot the word cloud
    plt.figure(figsize = (8, 6))
    plt.imshow(wordcloud, interpolation = 'bilinear')
    plt.axis('off')
    plt.title(f"Word Cloud - {model_name}")
    plt.show()

# %%
nonzeros = np.nonzero(weights)[0]

# %%
for i in nonzeros:
    print(reversed_order.get(i - 3, "?"))

# %%
x_test = pf.tensor(ds.x_test)
y_test = ds.y_test

# %%
pred = predict(x_test)
test_accuracy = accuracy_score(y_test, pred)

print(f"Test Accuracy: {test_accuracy: 3.4f}")
